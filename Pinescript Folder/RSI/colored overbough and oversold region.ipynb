# %%
//@version=5
indicator("RSI Overbought/Oversold", overlay=false)

// === INPUTS ===
rsiLength = input.int(14, title="RSI Length")
rsiSource = input.source(close, title="RSI Source")
overbought = input.int(70, title="Overbought Level")
oversold = input.int(30, title="Oversold Level")

// === RSI CALCULATION ===
rsi = ta.rsi(rsiSource, rsiLength)

// === PLOT RSI ===
rsiColor = rsi > overbought ? color.red : rsi < oversold ? color.lime : color.gray
plot(rsi, title="RSI", color=rsiColor, linewidth=2)

// === OVERBOUGHT/OVERSOLD LEVELS ===
hline(overbought, "Overbought", color=color.red, linestyle=hline.style_dashed)
hline(oversold, "Oversold", color=color.green, linestyle=hline.style_dashed)
hline(50, "Middle", color=color.gray)

// === BACKGROUND HIGHLIGHT ===
bgcolor(rsi > overbought ? color.new(color.red, 85) :
       rsi < oversold ? color.new(color.green, 85) : na)

# %% [markdown]
# ![image.png](attachment:image.png)
