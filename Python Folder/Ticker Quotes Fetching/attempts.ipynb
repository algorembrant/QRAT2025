# %% [markdown]
# attempts one
#
# Use python to fetch all ticker listed in MT5 platfform (this was already connected to Exness account) ,and its quotes such as spread and more. Print it on dataframe using continous number of columns.
