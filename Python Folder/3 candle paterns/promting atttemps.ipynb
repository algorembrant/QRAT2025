# %% [markdown]
# this strategy is reference from
# https://www.youtube.com/watch?v=2rwpLIqXRUA&t=1s

# %% [markdown]
# use python to datafetch XAUUSDc from MT5, data set from 3-minute timeframe, use whithe theme plotly, make the chart big (1000 width and 500 height)

# %% [markdown]
# This entry signal (black colored circle mark at the close-price) came from a pattern made by 3 candlesticks.
#
# For bearish pattern:
# Position 0 is a bearish candle.
# Position -1 is a bullish candle.
# Position -2 is a bullish candle.
# The current candle close (position 0) must engulf (lower than) the open price of 'position -1' candle, and the high of 'position -1' is higher than the highs of 'position -2' and 'position 0'. If this condition is met, mark the close price of the current candle.
#
# For bullish pattern:
# Position 0 is a bullish candle.
# Position -1 is a bearish candle.
# Position -2 is a bearish candle.
# The current candle close (position 0) must engulf (higher than) the open price of 'position -1' candle, and the low of 'position -1' is lower than the lows of 'position -2' and 'position 0'. If this condition is met, mark the close price of the current candle.

# %% [markdown]
# Make a backtest simulating real trade executions based on that previously discussed patterns . And,
#
# For bearish pattern:
# Sell-market at the close of the current candle, use 3 price unit worth of stoploss and the take profit is 2R-multiple. Risk 1% of the account per trade.
#
# For bearish pattern:
# Buy-market at the close of the current candle, use 3 price unit worth of stoploss and the take profit is 2R-multiple. Risk 1% of the account per trade.
#
# Mark the entries and exits. And put a green colored breakline if from entry to takeprofit, and red colored breakline if entry to stoploss.
# The initial capital is 1000.
# And plot the equity curve on separate graph with y-axis equity and x-axis trades.

# %% [markdown]
# too much losses but how about swapping the logic

# %% [markdown]
# how about hedge

# %% [markdown]
# delete all codes aside from price chart, body-upper pane, body-lower pane
