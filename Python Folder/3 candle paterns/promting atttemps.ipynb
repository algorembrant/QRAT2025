# %% [markdown]
# this strategy is reference from
# https://www.youtube.com/watch?v=2rwpLIqXRUA&t=1s

# %% [markdown]
# use python to datafetch XAUUSDc from MT5,

# %% [markdown]
# This is a three-candle pattern strategy.
# Let position 0 as the current candle. Position 0 must be a bullish engulfing the body of position -1 candle, and its low must be higher than position -1. The low of Position -1 must be higher than the lows of position 0 and position -2. If all condition is meet, then mark and entry signal at the close of position 0. Plot the candlestick chat and the signals. Use white themed plotly. Use 3-minute timeframe candles. Mark the entry signal black circle.

# %% [markdown]
# add the inverse version
