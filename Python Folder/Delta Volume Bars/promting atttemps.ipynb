# %% [markdown]
# use python to datafetch XAUUSDc from MT5, make a delta volume bar indicator

# %% [markdown]
# use mt5

# %% [markdown]
# how about using tick

# %% [markdown]
# fetch 3m-time frame data sets

# %% [markdown]
# also calculate the up & down tick volume

# %% [markdown]
# what is the lowest timeframe i could fetch from {like TF = mt5.TIMEFRAME_S1}?

# %% [markdown]
# how about the 10 seconds

# %% [markdown]
# how about 1 minute timeframe

# %% [markdown]
# This is a three-candle pattern strategy.
# Let position 0 as the current candle. Position 0 must be a bullish engulfing the body of position -1 candle, and its low must be higher than position -1. The low of Position -1 must be higher than the lows of position 0 and position -2. If all condition is meet, then mark and entry signal at the close of position 0.
