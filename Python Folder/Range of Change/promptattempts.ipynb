# %% [markdown]
# calculate the range bar by bar and plot the values on separate pane

# %% [markdown]
# how about add another pane for: calculate the body bar by bar and plot the values on separate pane

# %% [markdown]
# how about add another pane for: calculate the wick bar by bar and plot the values on separate pane
