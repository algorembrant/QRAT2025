# %% [markdown]
# make python code data fetching XAUUSDc 3-minute tiimeframe from MT5, use plotly white themed. Make an indicator where is calculate how much range bar by bar, plot these values on separate pane, make the candlestick chart large.

# %% [markdown]
# make another calculation but its body size, plot it on separate pane too\
# wicks too
