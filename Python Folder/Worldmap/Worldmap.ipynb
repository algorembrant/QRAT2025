# %%
import geopandas as gpd
import geodatasets
import matplotlib.pyplot as plt

# Load Natural Earth world map (modern method)
world = gpd.read_file(geodatasets.get_path("naturalearth.land"))

# Plot
fig, ax = plt.subplots(figsize=(15, 8))
world.plot(ax=ax, color="lightgray", edgecolor="black")

ax.set_title("World Map")
ax.axis("off")

plt.show()
# Out:
# Downloading file 'ne_110m_land.zip' from 'https://naciscdn.org/naturalearth/110m/physical/ne_110m_land.zip' to 'C:\Users\User\AppData\Local\geodatasets\geodatasets\Cache'.

# %%
import plotly.express as px
import pandas as pd

df = px.data.gapminder().query("year == 2007")

fig = px.choropleth(
    df,
    locations="iso_alpha",
    color="gdpPercap",
    hover_name="country",
    color_continuous_scale="Viridis",
    title="World GDP per Capita (2007)"
)

fig.show()

# %%
import folium

m = folium.Map(location=[20, 0], zoom_start=2)

folium.Marker(
    location=[14.5995, 120.9842],
    popup="Manila"
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b2067c9b141d57cd04e1eda7f942b7f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b2067c9b141d57cd04e1eda7f942b7f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b2067c9b141d57cd04e1eda7f942b7f = L.map(
#                 &quot;map_5b2067c9b141d57cd04e1eda7f942b7f&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84d894699f0f0c0d9a72c2157de86e5e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84d894699f0f0c0d9a72c2157de86e5e.addTo(map_5b2067c9b141d57cd04e1eda7f942b7f);
#
#
#             var marker_4eca33305d5608d896ac6f94ca2d7500 = L.marker(
#                 [14.5995, 120.9842],
#                 {
# }
#             ).addTo(map_5b2067c9b141d57cd04e1eda7f942b7f);
#
#
#         var popup_d2c6b8a6b043481414c3811b1ea30ef4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c482d09a5cbc1f26f6f56984c2545235 = $(`&lt;div id=&quot;html_c482d09a5cbc1f26f6f56984c2545235&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Manila&lt;/div&gt;`)[0];
#                 popup_d2c6b8a6b043481414c3811b1ea30ef4.setContent(html_c482d09a5cbc1f26f6f56984c2545235);
#
#
#
#         marker_4eca33305d5608d896ac6f94ca2d7500.bindPopup(popup_d2c6b8a6b043481414c3811b1ea30ef4)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(14, 7))
ax = plt.axes(projection=ccrs.Robinson())

ax.coastlines()
ax.set_global()
ax.set_title("World Map (Robinson Projection)")

plt.show()
# Out:
# C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\cartopy\io\__init__.py:242: DownloadWarning:
#
# Downloading: https://naturalearth.s3.amazonaws.com/110m_physical/ne_110m_coastline.zip

# %%
# !pip install geopandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geopandas
#   Downloading geopandas-1.1.1-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: numpy>=1.24 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from geopandas) (2.3.5)
# Collecting pyogrio>=0.7.2 (from geopandas)
#   Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl.metadata (6.0 kB)
# Requirement already satisfied: packaging in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from geopandas) (25.0)
# Requirement already satisfied: pandas>=2.0.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from geopandas) (2.3.3)
# Collecting pyproj>=3.5.0 (from geopandas)
#   Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=2.0.0 (from geopandas)
#   Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl.metadata (7.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=2.0.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pandas>=2.0.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pyogrio>=0.7.2->geopandas) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.8.2->pandas>=2.0.0->geopandas) (1.17.0)
# Downloading geopandas-1.1.1-py3-none-any.whl (338 kB)
# Downloading pyogrio-0.12.1-cp313-cp313-win_amd64.whl (22.9 MB)
#    ---------------------------------------- 0.0/22.9 MB ? eta -:--:--
#    --- ------------------------------------ 2.1/22.9 MB 10.9 MB/s eta 0:00:02
#    -------- ------------------------------- 4.7/22.9 MB 11.6 MB/s eta 0:00:02
#    ------------ --------------------------- 7.1/22.9 MB 11.7 MB/s eta 0:00:02
#    ---------------- ----------------------- 9.4/22.9 MB 11.6 MB/s eta 0:00:02
#    -------------------- ------------------- 11.8/22.9 MB 11.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 13.6/22.9 MB 11.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 16.3/22.9 MB 11.1 MB/s eta 0:00:01
#    -------------------------------- ------- 18.9/22.9 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 21.2/22.9 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------  22.8/22.9 MB 11.2 MB/s eta 0:00:01
#    ---------------------------------------- 22.9/22.9 MB 9.0 MB/s  0:00:02
# Downloading pyproj-3.7.2-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    -------------- ------------------------- 2.4/6.3 MB 11.2 MB/s eta 0:00:01
#    -------------------------- ------------- 4.2/6.3 MB 9.5 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------  6.3/6.3 MB 9.7 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 6.6 MB/s  0:00:00
# Downloading shapely-2.1.2-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ------ --------------------------------- 0.3/1.7 MB ? eta -:--:--
#    ------------ --------------------------- 0.5/1.7 MB 1.2 MB/s eta 0:00:02
#    ------------------------------------ --- 1.6/1.7 MB 3.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 2.4 MB/s  0:00:00
# Installing collected packages: shapely, pyproj, pyogrio, geopandas
#
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------------------------------------- 0/4 [shapely]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    ---------- ----------------------------- 1/4 [pyproj]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    -------------------- ------------------- 2/4 [pyogrio]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ------------------------------ --------- 3/4 [geopandas]
#    ---------------------------------------- 4/4 [geopandas]
#
# Successfully installed geopandas-1.1.1 pyogrio-0.12.1 pyproj-3.7.2 shapely-2.1.2
#   WARNING: The script pyproj.exe is installed in 'C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install folium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: folium in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (0.20.0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (3.1.6)
# Requirement already satisfied: numpy in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.3.5)
# Requirement already satisfied: requests in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2.32.5)
# Requirement already satisfied: xyzservices in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from folium) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from jinja2>=2.9->folium) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests->folium) (2025.11.12)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install cartopy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting cartopy
#   Downloading cartopy-0.25.0-cp313-cp313-win_amd64.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.23 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cartopy) (2.3.5)
# Requirement already satisfied: matplotlib>=3.6 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cartopy) (3.10.7)
# Requirement already satisfied: shapely>=2.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cartopy) (2.1.2)
# Requirement already satisfied: packaging>=21 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cartopy) (25.0)
# Collecting pyshp>=2.3 (from cartopy)
#   Downloading pyshp-3.0.3-py3-none-any.whl.metadata (65 kB)
# Requirement already satisfied: pyproj>=3.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from cartopy) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from matplotlib>=3.6->cartopy) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pyproj>=3.3.1->cartopy) (2025.11.12)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from python-dateutil>=2.7->matplotlib>=3.6->cartopy) (1.17.0)
# Downloading cartopy-0.25.0-cp313-cp313-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    -------- ------------------------------- 2.4/11.0 MB 15.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.0 MB 16.3 MB/s eta 0:00:01
#    ------------------------------------ --- 10.0/11.0 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 16.6 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.9 MB/s  0:00:01
# Downloading pyshp-3.0.3-py3-none-any.whl (58 kB)
# Installing collected packages: pyshp, cartopy
#
#    ---------------------------------------- 0/2 [pyshp]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    -------------------- ------------------- 1/2 [cartopy]
#    ---------------------------------------- 2/2 [cartopy]
#
# Successfully installed cartopy-0.25.0 pyshp-3.0.3
#   WARNING: The script cartopy_feature_download.exe is installed in 'C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
# !pip install geodatasets
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting geodatasets
#   Downloading geodatasets-2025.12.0-py3-none-any.whl.metadata (5.5 kB)
# Collecting pooch (from geodatasets)
#   Downloading pooch-1.8.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: platformdirs>=2.5.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pooch->geodatasets) (4.5.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pooch->geodatasets) (25.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from pooch->geodatasets) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->pooch->geodatasets) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->pooch->geodatasets) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->pooch->geodatasets) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\local\packages\pythonsoftwarefoundation.python.3.13_qbz5n2kfra8p0\localcache\local-packages\python313\site-packages (from requests>=2.19.0->pooch->geodatasets) (2025.11.12)
# Downloading geodatasets-2025.12.0-py3-none-any.whl (21 kB)
# Downloading pooch-1.8.2-py3-none-any.whl (64 kB)
# Installing collected packages: pooch, geodatasets
#
#    ---------------------------------------- 0/2 [pooch]
#    ---------------------------------------- 0/2 [pooch]
#    ---------------------------------------- 0/2 [pooch]
#    -------------------- ------------------- 1/2 [geodatasets]
#    -------------------- ------------------- 1/2 [geodatasets]
#    -------------------- ------------------- 1/2 [geodatasets]
#    -------------------- ------------------- 1/2 [geodatasets]
#    -------------------- ------------------- 1/2 [geodatasets]
#    ---------------------------------------- 2/2 [geodatasets]
#
# Successfully installed geodatasets-2025.12.0 pooch-1.8.2
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: C:\Users\User\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip
