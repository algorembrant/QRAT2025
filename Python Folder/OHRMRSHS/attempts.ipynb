# %% [markdown]
# Locate the candles from 8 pm to 9 pm (UTC+8, Asia/Manila timezone), and identify the highest and lowest points on the range. Make a box creating the said area. {}
#
# The logic doesn't matter; the timeframe used is as long as the logic is 'time-based'.

# %% [markdown]
# Make a backtesting strategy (using realistic trade executions like in a live environment). The preceding body-or-wick prices (after the range was established) revisit the median price of the range at least once, then 'place a buystop at the high of the range AND sellstop at the low of the range.' The stoploss price is at the median price of the range, and the take profit is 2R-multiple. 1% risk per trade with an initial balance of 1000. Print the dataframe of the raw trades. Plot the equity curve using white themed plotly. The trading setup is only
