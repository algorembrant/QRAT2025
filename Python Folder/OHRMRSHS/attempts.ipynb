# %% [markdown]
# Locate the candles from 8 pm to 9 pm (UTC+8, Asia/Manila timezone), and identify the highest and lowest points on the range. Make a box creating the said area. {}
#
# The logic doesn't matter; the timeframe used is as long as the logic is 'time-based'.

# %% [markdown]
# Do not delete anything, just add, Make a backtesting strategy (using realistic trade executions like in a live environment). The preceding body-or-wick prices (after the range was established) revisit the median price of the range at least once, then 'place a buystop at the high of the range AND sellstop at the low of the range.' The stoploss price is at the median price of the range, and the take profit is 2R-multiple. 1% risk per trade with an initial balance of 1000. Print the dataframe of the raw trades. The trading setup is only valid for its corresponding day (from market open to market close). Use a red linebreak breakline if the trade went from entry to stoploss from the corresponding time and price, and a green line break breakline from entry to takeprofit from the corresponding time and price.

# %% [markdown]
# theres a maximum two trades per session (from the corresponding range), one buystop and one sellstop

# %% [markdown]
# only place trades after it revisits the median price of the range

# %% [markdown]
# Do not delete anything, just add (add a random slipage of 0-2 price units every entry and exit, add a spread of 0.6 price units every entry and exit, add a commission of 2% every entry and exit.) Plot the equity curve using the raw trades dataframe, use plotly white themed, and also plot the drawdown percentage

# %% [markdown]
# as  s save
