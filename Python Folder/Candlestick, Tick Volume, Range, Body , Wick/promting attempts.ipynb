# %% [markdown]
# how about add another pane for: calculate {body-value minus wick-value} and plot it on separate pane

# %% [markdown]
# how about add another pane for: calculate ({body minus wick value} divided by range) and plot it on separate pane

# %% [markdown]
# how about add another pane for: calculate based {body minus wick value} and mark the close of the corresponding candlestick if the {body minus wick value} is positive

# %% [markdown]
# how about adding another pane: calculate based of (high-(body-high)) , this will only calculate the wick above the body of the candles

# %% [markdown]
# how about add another pane for: calculate {body value minus upper wick only value}
