# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mark the highest high and lowest low inside the 6am to 8am  range.
#
#
# let HHR be 'highest high of the range.'
# let LLR be 'lowest low of the range.'
# let EP be 'the extreme point of HHR or LLR'
# let BCC be 'breakout candle close'
#
# The judgement starts at 8:am, if the 3-minute BCC close above HHR and the previous candles' wicks (all canndles until EP) havent touched it yet, then buy the close of BCC and place the stoploss at the low of BCC accounting 1% risk of the current balance. Takeprofit at 10R-multiple. Or,
#
# The judgement starts at 8:am, if the 3-minute BCC close below LLR and the previous candles' wicks (all canndles until EP) havent touched it yet, then sell the close of BCC and place the stoploss at the high of BCC accounting 1% risk of the current balance. Takeprofit at 10R-multiple.
#
# Only one trade must trigger per day, either from BCC close above HHR or BCC close below LLR.

# %% [markdown]
# ![image.png](attachment:image.png)
