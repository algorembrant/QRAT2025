# %% [markdown]
# use new accouhnt
# exit the meta trader app
# refresh the dekstop screen
# open mt5
# triangle algo trading
# insert advisor
# set inputs
# OK
#
#
#
#
# issue, the strategy imidietly executes a trade as soon as i press ok (meaning that it doesnt rely on time intervals)
# i closed the position (in profits). lets see after 3 hours if it still executes. waiting till 2pm

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mark the highest high and lowest low inside the 22:00 PM to 0:00 AM  range.
#
#
# let HHR be 'highest high of the range.'
# let LLR be 'lowest low of the range.'
# let EP be 'the extreme point of HHR or LLR'
# let BCC be 'breakout candle close'
#
# The judgement starts at 0:00 AM, if the 3-minute BCC close above HHR and the previous candles' wicks (all canndles until EP) havent touched the HHR yet, then buy the close of BCC and place the stoploss at the low of BCC accounting 1% risk of the current balance. Takeprofit at 10R-multiple. Or,
#
# The judgement starts at 0:00 AM, if the 3-minute BCC close below LLR and the previous candles' wicks (all canndles until EP) havent touched the LLR yet, then sell the close of BCC and place the stoploss at the high of BCC accounting 1% risk of the current balance. Takeprofit at 10R-multiple.
#
# Only one trade must trigger per day, either from BCC close above HHR or BCC close below LLR.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2x volume blow
# premium zone
# tp 10R

# %% [markdown]
# ![image.png](attachment:image.png)
