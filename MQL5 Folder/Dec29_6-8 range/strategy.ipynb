# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# mark the highest high and lowest low inside the 6am to 8am  range.
#
#
# let HHR be 'highest high of the range.'
# let LLR be 'lowest low of the range.'
#
# The judgement starts at 8:am, if the 3-minute candle closes above the HHR and the previous candles' wick prices haven't touech the the HHR then place a market-buy at the close of the current candle and the stoploss is at the low of the current
