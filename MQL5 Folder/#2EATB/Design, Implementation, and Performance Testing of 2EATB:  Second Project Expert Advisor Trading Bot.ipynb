# %% [markdown]
# <div align="center">
#
# # **Design, Implementation, and Performance Testing of 2EATB:**
# # **Second Project Expert Advisor Trading Bot**
#
# **Albeos Rembrant¹³\***, **Lanticse Adrian²³**
# **November 2025**
#
# ¹ Chief Executive Officer
# ² Co-founder
# ³ Wildmind Quasars Quant Research & Algo Trading Group
#
# </div>
